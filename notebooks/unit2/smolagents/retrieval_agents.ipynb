# %% [markdown]
# # Building Agentic RAG Systems
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)

# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:the dependencies and login to our HF account to access the Inference API

# %%
# %pip install smolagents

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
# %pip install python-dotenv
import os
from dotenv import load_dotenv
from huggingface_hub import notebook_login

load_dotenv()
HF_AGENTS_COURSE=os.getenv("HF_TOKEN")

notebook_login()
# Out:
# Requirement already satisfied: python-dotenv in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Basic Retrieval with DuckDuckGo
#
# Let's build a simple agent that can search the web using DuckDuckGo. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# * Search for latest superhero party trends
# * Refine results to include luxury elements
# * Synthesize information into a complete plan
#
# Here's how Alfred's agent can achieve this:

# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

# Initialize the search tool
search_tool = DuckDuckGoSearchTool(max_results=10)

# Initialize the model
model = HfApiModel()

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   party_ideas = web_search("luxury superhero-themed party ideas")
#   print(party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# Let your superman show his own superpowers!Kids (and even adults) who love superheroes will fall in love with these
# incredible superhero theme party ideas that will bring out the kid in everyone! From decor ideas, party foods, and
# costume ideas to superhero-themed activities and superhero games, we have different ways to cover all of your party
# needs. These ideas will make you wish you were a ...
#
# [25 Superhero Party Ideas For All Ages](https://playideas.com/25-superhero-party-ideas/)
# These super cool superhero theme party ideas are so much fun and perfect for all ages! Boy, girl, teen, or adult,
# it doesn't matter. They are perfect for your next superhero-themed food and party! We have found some amazingly
# fantastic party ideas from treats, decor, crafts to souvenirs for different sorts of superheroes, from Batman,
# Super ...
#
# [The Best Superhero Party Ideas For An Epic Party - Smart Party
# Planning](https://smartpartyplanning.com/superhero-party-ideas/)
# Awesome superhero party ideas that will have your kids showing off their superhero powers in no time at all. With
# ideas for decorations, food and party games you will easily win the status of superhero mom. These ideas can be
# achieved on a budget with a bit of DIY. The kids are going to love them. Related articles: 5 Awesome Batman Party
# Ideas
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
# Patriotic 4th of July recipes can easily be repurposed as Captain America themed Superhero party food, such as
# these recipes for Red, White, and Blue Chocolate Dipped Strawberries (below left, by Nicole at Baking Bites) or
# Jell-O cut into star shapes (below right, by Ali from Gimme Some Oven).
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Browse a wide range of superhero party ideas and inspiration, from photos and templates in a stunning selection of
# styles and colours. ... all these ingenious concepts and more are in our special selection of superhero-themed
# designs and photos. Have a quick browse and find some excellent ideas for your party! Yellow Blue Red Superhero
# Pattern ...
#
# [Check out These Fantastic 14 Must-See Superhero Party
# Ideas!](https://www.catchmyparty.com/blog/14-must-see-superhero-party-ideas)
# Superhero parties have always been a huge hit with kids. Movies like Iron-man, Batman, Avengers, and so many more
# have made the theme the mega success it is. So, if you have a little boy or a young man dying for a superhero
# party, you won't want to miss these 14 must-see superhero party ideas.
#
# [30+ Easy Superhero Party Ideas You Can Perfect on a
# Budget](https://www.frugalcouponliving.com/superhero-party-ideas/)
# Enjoy the best DIY superhero party ideas, recipes, décor, games and more to make planning a party easy-peasy.
# Planning a themed party can be a lot of fun. And with so many popular Marvel, Avengers and DC movies being released
# in recent years, it's no wonder that superhero parties are becoming increasingly popular.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Superhero-themed parties have become a beloved trend, offering an exciting way to celebrate special occasions. The
# thrill of donning capes and masks, the vibrant decorations, and the heroic atmosphere make these parties a hit
# among kids and adults alike. In this guide, we'll explore Marvel superhero party ideas, ensuring your celebration
# is as epic as the comics and movies themselves ...
#
# [Superhero Party Ideas | PartyWizz Blog](https://partywizz.com/blog/family/party-ideas/superhero-party-ideas/)
# Party Bags. Use superhero-themed paper party bags - Amazon have a good selection - or keep costs down with plain
# paper bags and decorate/personalise them yourself. This is a task you could definitely delegate to your own small
# superhero! Contents could include: Superhero stickers; Superhero snap bands; Superhero temporary tattoos; Lego ...
#
# [Superhero Party Ideas - Theme A Party](https://themeaparty.com/superhero-party-ideas)
# You can also mix things up with superhero groups for your child's party theme. Marvel Comics, the Fantastic Four,
# Stan Lee originals, super machines/half-man, half-droids and others give you more room for flexibility in your
# planning and decorating. Power Foods. Refreshments that match the theme will really get your child's guests in the
# mood.
#
# Out: None
# [Step 0: Duration 4.85 seconds| Input tokens: 2,086 | Output tokens: 74]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   decorations = web_search("luxury superhero-themed party decorations")
#   entertainment = web_search("luxury superhero-themed party entertainment")
#   catering = web_search("luxury superhero-themed party catering")
#
#   print("***Decorations:***")
#   print(decorations)
#   print("\n***Entertainment:***")
#   print(entertainment)
#   print("\n***Catering:***")
#   print(catering)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ***Decorations:***
# ## Search Results
#
# [Amazon.com: Superhero Party
# Decorations](https://www.amazon.com/superhero-party-decorations/s?k=superhero+party+decorations)
# Luxury Stores; Sports & Outdoors; Sell; Find a Gift ... 12 Inch Metallic Silver Latex Balloons Helium Blue Red
# Confetti Balloons for Graduation Boys Birthday Super Hero Spider Party Decorations. 4.6 out of 5 stars. 458. ...
# Blue Red Yellow Balloons for Baby Shower, Carnival, Circus, Superhero Theme Birthday Party Decor. 4.5 out of 5
# stars. 52 ...
#
# [Superhero Party Supplies and Decorations | The Party
# Darling](https://thepartydarling.com/collections/superhero-party-supplies-and-decorations)
# Throw an action-packed party using our comic book superhero party supplies and decorations. Our superhero birthday
# decorations and party favors will save the day. - ... Themes; Party Supplies; Holidays & Occasions; Clearance.
# THEMES. Theme (a-c) Airplane; Alice in Wonderland; Baking Party; Baseball; Boho Rainbow; Botanical; Bows; Bumble
# Bee; Bunny;
#
# [Superhero Party Decorations - Etsy](https://www.etsy.com/market/superhero_party_decorations)
# Check out our superhero party decorations selection for the very best in unique or custom, handmade pieces from our
# party & gifting shops. ... BIG CUTOUT Super Hero Party Super Hero Buildings Super Hero Party Ideas Cutout Superhero
# Party Decor Life Size Cutout Cityscape Buildings (84) $ 7.44. Digital Download Add to Favorites ...
#
# [Amazon.com: Superhero Birthday Party
# Decorations](https://www.amazon.com/Superhero-Birthday-Party-Decorations/s?k=Superhero+Birthday+Party+Decorations)
# Superhero Party Supplies Superhero Party Decorations, 20Pcs Superhero Balloons, 1Pcs Happy Birthday Banner, 13Pcs
# Superhero Cake and Cupcake Toppers for Kids Birthday Party 4.5 out of 5 stars 152
#
# [Super Hero Party Supplies: Transform Your Party Space Into a Heroic
# ...](https://www.bulkpartysupplies.com/collections/super-hero-party-theme)
Superhero Company](https://thesuperherocompany.com/superhero-parties/)
# Voted the #1 Superhero Party Company in Canada, we specialize in Superhero and Star Warrior Birthday Parties,
# corporate appearances, character meet and greets, and specially themed events around Superhero and other popular
# characters.
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/catering-design/event-design-decor/media-gallery/13479192/15-ideas-for-superheroth
# emed-events)
# New York's Robin Hood Foundation, which hosts one of the largest and most successful benefits in the city, tapped
# contacts at DC Comics to help create a superhero theme for its 2011 gala. The planning and design team created an
# emblem and slogan—"the forces of good are gathering"—that marked the night's invite and main cocktail area.
#
# [Superhero Party for 3-7 Years - Captain Fantastic US](https://cfparties.com/parties/superhero-parties/)
# With such an inclusive theme, fun is guaranteed! This is our most gender-neutral party type, making it the most
# suitable and appealing choice for a mixed audience of boys and girls! ... Every Superhero party package is led by
# an expert entertainer, ensuring maximum peace of mind. Our entertainers bring a diverse array of tried-and-tested
# crowd ...
#
# [Themed Birthday Party Ideas: From Superheroes to Princesses](https://whattogetmy.com/themed-birthday-party-ideas/)
# Complete the experience with superhero-themed party favors and a magnificent superhero-themed birthday cake.
# Superhero Birthday Party Ideas: Unleash the Hero Within! ... With a multi-themed extravaganza, you can create a
# birthday party catering to young imaginations' diverse interests. Providing distinct zones dedicated to different
# themes ...
#
# [Heroes and Villains: The Ultimate Guide to Superhero
# Parties](https://scarlettentertainment.com/gb/blog/heroes-and-villains-the-ultimate-guide-to-superhero-parties)
# Worshipped by millions, comic book characters are more popular than ever, which consequently make heroes and
# villains parties a steady entertainment trend. Especially popular for Halloween party themes, Superhero parties are
# the go-to theme for any sort of event these days, and be aware: villains are now VIP guests!
#
# [Evntwrks - Luxury Event Production Company | California](https://evntwrks.com/)
# EVNTWRKS is a full service catering and event production company specializing in one stop shopping for weddings,
# corporate events, conferences, destination events! Our seasoned event professionals have designed and produced
# events from 10 to 15,000 guests in premiere locations across the country. Our Services. CATERING. VIEW MORE.
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Inform guests of a superhero theme through the invitation and let them get creative with costumes, or get specific
# with a Marvel- or DC-specific spin. Send out invitations that imitate a front page of a newspaper with
# crime-fighting headlines, decorate your space with metropolitan-inspired skyline pieces to create a Gotham City
# ambience and ...
#
# Out: None
# [Step 1: Duration 12.95 seconds| Input tokens: 5,363 | Output tokens: 213]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Decorations
#   decorations_description = """
#   ### Superhero Party Decorations
#   - **Amazon**: Offering a variety of superhero-themed decorations such as balloons, banners, cake toppers, and
#   prop cutouts.
#   - **The Party Darling**: Provides unique superhero party supplies and decorations, including cutout cityscapes
#   and party favors.
#   - **Etsy**: Features handmade superhero party decorations, like life-size cutout buildings and cascade
#   centerpieces.
#   - **Bulk Party Supplies**: Provides inflatable characters, fabric capes, and action sign cutouts.
#   - **Target**: Offers superhero-themed party supplies like plates, banners, and balloons.
#   - **PartyCheap**: Features hero action sign cutouts and other superhero decorations.
#   - **Paperless Post Party Shop**: Provides superhero-themed invitations, plates, and banners.
#   - **American Carnival Mart**: Offers superhero-themed party supplies, party favors, and decorations.
#   """
#
#   # Entertainment
#   entertainment_description = """
#   ### Superhero Party Entertainment
#   - **Wishing Well Entertainment and Parties**: Provides famous film and TV characters, singers, and
#   impersonators.
#   - **Blue Balloon Parties**: Offers superhero party entertainers, bounce houses, and various extensions.
#   - **The Cinderella Company**: Offers a wide range of characters, including superheroes, for your celebration.
#   - **The Superhero Company**: Specializes in superhero and Star Warrior birthday parties, corporate appearances,
#   and character meet-and-greets.
#   - **Fairytale Entertainment**: Provides superhero package entertainment with party activities for children.
#   - **Star Brite Entertainment**: Offers a Superhero Party Package with a villain stunt show and activities.
#   - **Superhero Time**: Provides costumed heroes for parties, for hire through GigSalad.
#   - **Superhero Fun Adventure**: Offers outdoor and indoor superhero-themed celebrations.
#   - **The Bash**: Provides ideas for party activities and themes.
#   """
#
#   # Catering
#   catering_description = """
#   ### Superhero Party Catering
#   - **Little Lux Catering**: Offers themed party packages with arches, backdrops, and superhero-themed grazing
#   tables.
#   - **Carrie Dove Catering**: Provides exceptional food for special events, including themed food stations and
#   five-course dinners.
#   - **EVNTWRKS**: Specializes in catering and event production with professionals experienced in producing events
#   from 10 to 15,000 guests.
#   - **Captain Fantastic US**: Offers superhero party packages with expert entertainers.
#   - **What to Get Me**: Provides party favors and magnificent superhero-themed birthday cakes.
#   - **Scarlett Entertainment**: Specializes in events featuring heroes and villains.
#   - **The Bash**: Provides ideas for themed party menus and activities.
#   """
#
#   # Compile the final answer
#   final_description = f"{decorations_description}\n{entertainment_description}\n{catering_description}"
#
#   # Print the final description for review
#   print(final_description)
#
#   # Provide the final answer
#   final_answer(final_description)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# ### Superhero Party Decorations
# - **Amazon**: Offering a variety of superhero-themed decorations such as balloons, banners, cake toppers, and prop
# cutouts.
# - **The Party Darling**: Provides unique superhero party supplies and decorations, including cutout cityscapes and
# party favors.
# - **Etsy**: Features handmade superhero party decorations, like life-size cutout buildings and cascade
# centerpieces.
# - **Bulk Party Supplies**: Provides inflatable characters, fabric capes, and action sign cutouts.
# - **Target**: Offers superhero-themed party supplies like plates, banners, and balloons.
# - **PartyCheap**: Features hero action sign cutouts and other superhero decorations.
# - **Paperless Post Party Shop**: Provides superhero-themed invitations, plates, and banners.
# - **American Carnival Mart**: Offers superhero-themed party supplies, party favors, and decorations.
#
#
# ### Superhero Party Entertainment
# - **Wishing Well Entertainment and Parties**: Provides famous film and TV characters, singers, and impersonators.
# - **Blue Balloon Parties**: Offers superhero party entertainers, bounce houses, and various extensions.
# - **The Cinderella Company**: Offers a wide range of characters, including superheroes, for your celebration.
# - **The Superhero Company**: Specializes in superhero and Star Warrior birthday parties, corporate appearances, and
# character meet-and-greets.
# - **Fairytale Entertainment**: Provides superhero package entertainment with party activities for children.
# - **Star Brite Entertainment**: Offers a Superhero Party Package with a villain stunt show and activities.
# - **Superhero Time**: Provides costumed heroes for parties, for hire through GigSalad.
# - **Superhero Fun Adventure**: Offers outdoor and indoor superhero-themed celebrations.
# - **The Bash**: Provides ideas for party activities and themes.
#
#
# ### Superhero Party Catering
# - **Little Lux Catering**: Offers themed party packages with arches, backdrops, and superhero-themed grazing
# tables.
# - **Carrie Dove Catering**: Provides exceptional food for special events, including themed food stations and
# five-course dinners.
# - **EVNTWRKS**: Specializes in catering and event production with professionals experienced in producing events
# from 10 to 15,000 guests.
# - **Captain Fantastic US**: Offers superhero party packages with expert entertainers.
# - **What to Get Me**: Provides party favors and magnificent superhero-themed birthday cakes.
# - **Scarlett Entertainment**: Specializes in events featuring heroes and villains.
# - **The Bash**: Provides ideas for themed party menus and activities.
#
#
# Out - Final answer:
# ### Superhero Party Decorations
# - **Amazon**: Offering a variety of superhero-themed decorations such as balloons, banners, cake toppers, and prop
# cutouts.
# - **The Party Darling**: Provides unique superhero party supplies and decorations, including cutout cityscapes and
# party favors.
# - **Etsy**: Features handmade superhero party decorations, like life-size cutout buildings and cascade
# centerpieces.
# - **Bulk Party Supplies**: Provides inflatable characters, fabric capes, and action sign cutouts.
# - **Target**: Offers superhero-themed party supplies like plates, banners, and balloons.
# - **PartyCheap**: Features hero action sign cutouts and other superhero decorations.
# - **Paperless Post Party Shop**: Provides superhero-themed invitations, plates, and banners.
# - **American Carnival Mart**: Offers superhero-themed party supplies, party favors, and decorations.
#
#
# ### Superhero Party Entertainment
# - **Wishing Well Entertainment and Parties**: Provides famous film and TV characters, singers, and impersonators.
# - **Blue Balloon Parties**: Offers superhero party entertainers, bounce houses, and various extensions.
# - **The Cinderella Company**: Offers a wide range of characters, including superheroes, for your celebration.
# - **The Superhero Company**: Specializes in superhero and Star Warrior birthday parties, corporate appearances, and
# character meet-and-greets.
# - **Fairytale Entertainment**: Provides superhero package entertainment with party activities for children.
# - **Star Brite Entertainment**: Offers a Superhero Party Package with a villain stunt show and activities.
# - **Superhero Time**: Provides costumed heroes for parties, for hire through GigSalad.
# - **Superhero Fun Adventure**: Offers outdoor and indoor superhero-themed celebrations.
# - **The Bash**: Provides ideas for party activities and themes.
#
#
# ### Superhero Party Catering
# - **Little Lux Catering**: Offers themed party packages with arches, backdrops, and superhero-themed grazing
# tables.
# - **Carrie Dove Catering**: Provides exceptional food for special events, including themed food stations and
# five-course dinners.
# - **EVNTWRKS**: Specializes in catering and event production with professionals experienced in producing events
# from 10 to 15,000 guests.
# - **Captain Fantastic US**: Offers superhero party packages with expert entertainers.
# - **What to Get Me**: Provides party favors and magnificent superhero-themed birthday cakes.
# - **Scarlett Entertainment**: Specializes in events featuring heroes and villains.
# - **The Bash**: Provides ideas for themed party menus and activities.
# [Step 2: Duration 30.03 seconds| Input tokens: 11,872 | Output tokens: 835]
# ### Superhero Party Decorations
# - **Amazon**: Offering a variety of superhero-themed decorations such as balloons, banners, cake toppers, and prop cutouts.
# - **The Party Darling**: Provides unique superhero party supplies and decorations, including cutout cityscapes and party favors.
# - **Etsy**: Features handmade superhero party decorations, like life-size cutout buildings and cascade centerpieces.
# - **Bulk Party Supplies**: Provides inflatable characters, fabric capes, and action sign cutouts.
# - **Target**: Offers superhero-themed party supplies like plates, banners, and balloons.
# - **PartyCheap**: Features hero action sign cutouts and other superhero decorations.
# - **Paperless Post Party Shop**: Provides superhero-themed invitations, plates, and banners.
# - **American Carnival Mart**: Offers superhero-themed party supplies, party favors, and decorations.
#
#
# ### Superhero Party Entertainment
# - **Wishing Well Entertainment and Parties**: Provides famous film and TV characters, singers, and impersonators.
# - **Blue Balloon Parties**: Offers superhero party entertainers, bounce houses, and various extensions.
# - **The Cinderella Company**: Offers a wide range of characters, including superheroes, for your celebration.
# - **The Superhero Company**: Specializes in superhero and Star Warrior birthday parties, corporate appearances, and character meet-and-greets.
# - **Fairytale Entertainment**: Provides superhero package entertainment with party activities for children.
# - **Star Brite Entertainment**: Offers a Superhero Party Package with a villain stunt show and activities.
# - **Superhero Time**: Provides costumed heroes for parties, for hire through GigSalad.
# - **Superhero Fun Adventure**: Offers outdoor and indoor superhero-themed celebrations.
# - **The Bash**: Provides ideas for party activities and themes.
#
#
# ### Superhero Party Catering
# - **Little Lux Catering**: Offers themed party packages with arches, backdrops, and superhero-themed grazing tables.
# - **Carrie Dove Catering**: Provides exceptional food for special events, including themed food stations and five-course dinners.
# - **EVNTWRKS**: Specializes in catering and event production with professionals experienced in producing events from 10 to 15,000 guests.
# - **Captain Fantastic US**: Offers superhero party packages with expert entertainers.
# - **What to Get Me**: Provides party favors and magnificent superhero-themed birthday cakes.
# - **Scarlett Entertainment**: Specializes in events featuring heroes and villains.
# - **The Bash**: Provides ideas for themed party menus and activities.

# %% [markdown]
# The agent follows this process:
#
# 1. **Analyzes the Request:** Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# 2. **Performs Retrieval:**  The agent leverages DuckDuckGo to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# 3. **Synthesizes Information:** After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# 4. **Stores for Future Reference:** The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks.

# %% [markdown]
# ## Custom Knowledge Base Tool
#
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
# %pip install langchain-community rank_bm25
# Out:
# Requirement already satisfied: langchain-community in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (0.3.18)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.37 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (0.3.40)
# Requirement already satisfied: langchain<1.0.0,>=0.3.19 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (0.3.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (2.0.38)
# Requirement already satisfied: requests<3,>=2 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (3.11.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (0.3.11)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy<2,>=1.26.4 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.6 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (0.3.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.19->langchain-community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.37->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2025.1.31)
# Requirement already satisfied: anyio in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.37->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.19->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/fperez/dev/agents-course/.venv/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, HfApiModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=HfApiModel(), verbosity_level=2)

# Example usage
response = agent.run(
    # "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
    "Make a plan for a luxury superhero-themed party. Then find ideas for entertainment, catering, and decoration options to make an exceptional party. Do not use code when you don't need to and do the task for yourself. Avoid redundancies and return the result in markdown format."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Make a plan for a luxury superhero-themed party. Then find ideas for entertainment, catering, and decoration    │
# │ options to make an exceptional party. Do not use code when you don't need to and do the task for yourself.      │
# │ Avoid redundancies and return the result in markdown format.                                                    │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# ### Thought:
# To create a luxury superhero-themed party, I will follow these steps:
# 1. **Research Party Ideas**: Use the `party_planning_retriever` tool to get relevant party planning ideas for
# superhero themes.
# 2. **Plan Entertainment, Catering, and Decoration**: Based on the retrieved ideas, I will formulate detailed plans
# for entertainment, catering, and decoration.
# 3. **Format the Result**: Present the plan in markdown format.
#
# ### Code:
# ```py
# superhero_party_ideas = party_planning_retriever(query="superhero-themed luxury party")
# print(superhero_party_ideas)
# ```<end_code>
#
# ### Observation:
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   superhero_party_ideas = party_planning_retriever(query="superhero-themed luxury party")
#   print(superhero_party_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 0: Duration 5.78 seconds| Input tokens: 2,136 | Output tokens: 131]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# 500 Server Error: Internal Server Error for url:
# https://api-inference.huggingface.co/models/Qwen/Qwen2.5-Coder-32B-Instruct/v1/chat/completions (Request ID:
# Root=1-67c0e564-726df556173dc6ac38dde69a;49ebbae4-27d8-4937-ba8f-e543479fdbfb)
#
# Model too busy, unable to get response in less than 60 second(s)
# [Step 1: Duration 60.28 seconds| Input tokens: 4,272 | Output tokens: 262]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# ### Thought:
# Since the API was too busy, I will manually craft the luxury superhero-themed party plan using the general ideas
# from the previous suggestions.
#
# ### Plan:
# #### Entertainment:
# 1. **Interactive VR Experiences**: Set up VR stations where guests can engage in superhero-themed simulations or
# compete in themed games. This adds an element of fun and interaction.
# 2. **Live Performances**: Hire a live band that plays superhero soundtrack themes. Include a few special
# performances like a caped Lantern or a cued Batman portrayal.
#
# #### Catering:
# 1. **Superhero-Inspired Dishes**: Serve dishes named after superheroes, such as "The Hulk's Green Smoothie" and
# "Iron Man's Power Steak." Offer a variety of gourmet options catered to superhero tastes.
# 2. **Signature Cocktails**: Introduce signature cocktails like the "Batman Malt Liquor" and "Wolverine Fruity
# Punch." Make each cocktail booth look like a superhero lab or cozy cafes.
#
# #### Decoration:
# 1. **Superhero Logos and City Projections**: Decorate with large, iconic superhero logos and projections of cities
# like Gotham and Metropolis. Projected visual elements will make the party venue feel alive.
# 2. **Gold Accents and Velvet Curtains**: Use gold accents and velvet curtains for a luxurious touch. Incorporate
# twinkling, colorful LED lights to resemble the night sky and the glow from skyscrapers.
# 3. **Superhero-Themed Photo Booth**: Set up a photo booth with superhero masks, capes, and backdrops. Include props
# for guests to take fun, memorable photos.
#
# By integrating these ideas, we can create a luxurious yet fun superhero-themed party at Wayne Manor!
#
# ### Code:
# ```py
# final_answer("""
# # Luxury Superhero-Themed Party Plan
#
# ## Entertainment
#
# 1. **Interactive VR Experiences**:
#    - Set up VR stations where guests can engage in superhero-themed simulations or compete in themed games.
#
# 2. **Live Performances**:
#    - Hire a live band that plays superhero soundtrack themes.
#    - Include special performances like a caped Lantern or a cued Batman portrayal.
#
# ## Catering
#
# 1. **Superhero-Inspired Dishes**:
#    - Serve dishes named after superheroes, such as "The Hulk's Green Smoothie" and "Iron Man's Power Steak."
#    - Offer a variety of gourmet options catered to superhero tastes.
#
# 2. **Signature Cocktails**:
#    - Introduce signature cocktails like the "Batman Malt Liquor" and "Wolverine Fruity Punch."
#    - Make each cocktail booth look like a superhero lab or cozy cafes.
#
# ## Decoration
#
# 1. **Superhero Logos and City Projections**:
#    - Decorate with large, iconic superhero logos and projections of cities like Gotham and Metropolis.
#
# 2. **Gold Accents and Velvet Curtains**:
#    - Use gold accents and velvet curtains for a luxurious touch.
#    - Incorporate twinkling, colorful LED lights to resemble the night sky and the glow from skyscrapers.
#
# 3. **Superhero-Themed Photo Booth**:
#    - Set up a photo booth with superhero masks, capes, and backdrops.
#    - Include props for guests to take fun, memorable photos.
# """)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("""
#   # Luxury Superhero-Themed Party Plan
#
#   ## Entertainment
#
#   1. **Interactive VR Experiences**:
#      - Set up VR stations where guests can engage in superhero-themed simulations or compete in themed games.
#
#   2. **Live Performances**:
#      - Hire a live band that plays superhero soundtrack themes.
#      - Include special performances like a caped Lantern or a cued Batman portrayal.
#
#   ## Catering
#
#   1. **Superhero-Inspired Dishes**:
#      - Serve dishes named after superheroes, such as "The Hulk's Green Smoothie" and "Iron Man's Power Steak."
#      - Offer a variety of gourmet options catered to superhero tastes.
#
#   2. **Signature Cocktails**:
#      - Introduce signature cocktails like the "Batman Malt Liquor" and "Wolverine Fruity Punch."
#      - Make each cocktail booth look like a superhero lab or cozy cafes.
#
#   ## Decoration
#
#   1. **Superhero Logos and City Projections**:
#      - Decorate with large, iconic superhero logos and projections of cities like Gotham and Metropolis.
#
#   2. **Gold Accents and Velvet Curtains**:
#      - Use gold accents and velvet curtains for a luxurious touch.
#      - Incorporate twinkling, colorful LED lights to resemble the night sky and the glow from skyscrapers.
#
#   3. **Superhero-Themed Photo Booth**:
#      - Set up a photo booth with superhero masks, capes, and backdrops.
#      - Include props for guests to take fun, memorable photos.
#   """)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer:
# # Luxury Superhero-Themed Party Plan
#
# ## Entertainment
#
# 1. **Interactive VR Experiences**:
#    - Set up VR stations where guests can engage in superhero-themed simulations or compete in themed games.
#
# 2. **Live Performances**:
#    - Hire a live band that plays superhero soundtrack themes.
#    - Include special performances like a caped Lantern or a cued Batman portrayal.
#
# ## Catering
#
# 1. **Superhero-Inspired Dishes**:
#    - Serve dishes named after superheroes, such as "The Hulk's Green Smoothie" and "Iron Man's Power Steak."
#    - Offer a variety of gourmet options catered to superhero tastes.
#
# 2. **Signature Cocktails**:
#    - Introduce signature cocktails like the "Batman Malt Liquor" and "Wolverine Fruity Punch."
#    - Make each cocktail booth look like a superhero lab or cozy cafes.
#
# ## Decoration
#
# 1. **Superhero Logos and City Projections**:
#    - Decorate with large, iconic superhero logos and projections of cities like Gotham and Metropolis.
#
# 2. **Gold Accents and Velvet Curtains**:
#    - Use gold accents and velvet curtains for a luxurious touch.
#    - Incorporate twinkling, colorful LED lights to resemble the night sky and the glow from skyscrapers.
#
# 3. **Superhero-Themed Photo Booth**:
#    - Set up a photo booth with superhero masks, capes, and backdrops.
#    - Include props for guests to take fun, memorable photos.
# [Step 2: Duration 29.22 seconds| Input tokens: 6,926 | Output tokens: 928]
# # Luxury Superhero-Themed Party Plan
#
# ## Entertainment
#
# 1. **Interactive VR Experiences**:
#    - Set up VR stations where guests can engage in superhero-themed simulations or compete in themed games.
#
# 2. **Live Performances**:
#    - Hire a live band that plays superhero soundtrack themes.
#    - Include special performances like a caped Lantern or a cued Batman portrayal.
#
# ## Catering
#
# 1. **Superhero-Inspired Dishes**:
#    - Serve dishes named after superheroes, such as "The Hulk's Green Smoothie" and "Iron Man's Power Steak."
#    - Offer a variety of gourmet options catered to superhero tastes.
#
# 2. **Signature Cocktails**:
#    - Introduce signature cocktails like the "Batman Malt Liquor" and "Wolverine Fruity Punch."
#    - Make each cocktail booth look like a superhero lab or cozy cafes.
#
# ## Decoration
#
# 1. **Superhero Logos and City Projections**:
#    - Decorate with large, iconic superhero logos and projections of cities like Gotham and Metropolis.
#
# 2. **Gold Accents and Velvet Curtains**:
#    - Use gold accents and velvet curtains for a luxurious touch.
#    - Incorporate twinkling, colorful LED lights to resemble the night sky and the glow from skyscrapers.
#
# 3. **Superhero-Themed Photo Booth**:
#    - Set up a photo booth with superhero masks, capes, and backdrops.
#    - Include props for guests to take fun, memorable photos.

# %% [markdown]
# This enhanced agent can:
# 1. First check the documentation for relevant information
# 2. Combine insights from the knowledge base
# 3. Maintain conversation context through memory
